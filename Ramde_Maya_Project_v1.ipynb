# %%
import os
import os.path as op
import json
from pathlib import Path
import shutil
import logging
import numpy as np
from tqdm import tqdm
from skimage import io
import keras
import math

import tensorflow as tf

from matplotlib import pyplot as plt
import random
from PIL import Image
from tensorflow.keras import layers, models, regularizers, callbacks
import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, ReLU, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Mount drive to Colab notebook
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Uploaded data.zip to my google drive. Now, unzip it and store in 552_project_data folder
# zip_file_path = '/content/drive/MyDrive/Colab Notebooks/data.zip'
# destination_folder = '/content/drive/MyDrive/552_project_data/'
# !unzip "$zip_file_path" -d "$destination_folder"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16257_16556_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16556_16855_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16257_16556_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16556_16855_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18350_18649_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19247_19546_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19546_19845_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19247_19546_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19546_19845_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15958_16257_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18051_18350_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16855_17154_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15659_15958_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17154_17453_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15360_15659_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15659_15958_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18649_18948_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17154_17453_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16855_17154_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15659_15958_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17154_17453_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16855_17154_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15360_15659_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18350_18649_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19546_19845_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15958_16257_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19247_19546_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_15958_16257_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18051_18350_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17453_17752_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16257_16556_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_19845_20144_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18350_18649_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_16556_16855_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18649_18948_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_20144_20443_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18649_18948_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17752_18051_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18051_18350_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_18948_19247_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_020415_1195_15360_20480_5120_10240/tiles/frost/ESP_020415_1195_17752_18051_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_8110_8409.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_6615_6914.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_8409_8708.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_5718_6017.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_7811_8110.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_9605_9904.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_6316_6615.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_9306_9605.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17453_17752_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16257_16556_7213_7512.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16556_16855_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_5419_5718.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15360_15659_9904_10203.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17752_18051_5120_5419.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_9007_9306.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_17154_17453_6914_7213.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_8708_9007.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15958_16257_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_15659_15958_6017_6316.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/labels/background/ESP_049512_1310_16855_17154_7512_7811.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17752_18051_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17752_18051_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17752_18051_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17752_18051_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15659_15958_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16556_16855_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17453_17752_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16257_16556_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15360_15659_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_16855_17154_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_15958_16257_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_049512_1310_15360_18528_5120_10240/tiles/background/ESP_049512_1310_17154_17453_7213_7512.png
# ...
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10838_11137_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12034_12333_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13230_13529_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11436_11735_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13828_14127_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11137_11436_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14127_14426_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11137_11436_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14725_15024_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12931_13230_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14725_15024_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13230_13529_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13828_14127_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10838_11137_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14127_14426_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_15024_15323_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13828_14127_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12333_12632_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11436_11735_9605_9904.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14426_14725_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_15024_15323_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12333_12632_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12333_12632_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14725_15024_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12034_12333_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10838_11137_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11436_11735_8409_8708.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12034_12333_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_15024_15323_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_5718_6017.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10838_11137_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12333_12632_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10838_11137_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14127_14426_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12931_13230_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12034_12333_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14426_14725_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_9007_9306.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11137_11436_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11436_11735_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14725_15024_7512_7811.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10539_10838_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13529_13828_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_15024_15323_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12632_12931_6316_6615.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13230_13529_8708_9007.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13828_14127_7811_8110.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14426_14725_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11436_11735_6017_6316.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_7213_7512.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_13230_13529_6914_7213.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11137_11436_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_6615_6914.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_12931_13230_5419_5718.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14426_14725_5120_5419.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_14127_14426_9306_9605.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_10240_10539_8110_8409.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_038058_1205_10240_15360_5120_10240/tiles/frost/ESP_038058_1205_11735_12034_9904_10203.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_34308_34906_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_31916_32514_3588_4186.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_33710_34308_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_32514_33112_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_30720_31318_3588_4186.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_31318_31916_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_30720_31318_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_32514_33112_3588_4186.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_31318_31916_3588_4186.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_31916_32514_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_33112_33710_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/labels/background/ESP_026885_2295_34906_35504_4186_4784.json
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_30720_31318_3588_4186.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_32514_33112_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_33710_34308_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_31318_31916_3588_4186.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_31916_32514_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_34906_35504_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_31318_31916_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_32514_33112_3588_4186.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_30720_31318_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_33112_33710_4186_4784.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_31916_32514_3588_4186.png
#   inflating: /content/drive/MyDrive/552_project_data/data/ESP_026885_2295_30720_35840_0_5120/tiles/background/ESP_026885_2295_34308_34906_4186_4784.png

# %%
# Logging configuration
logging.basicConfig(level=logging.INFO,
                    datefmt='%H:%M:%S',
                    format='%(asctime)s | %(levelname)-5s | %(module)-15s | %(message)s')

IMAGE_SIZE = (299, 299)  # All images contained in this dataset are 299x299 (originally, to match Inception v3 input size)
SEED = 17

# Head directory containing all image subframes. Update with the relative path of your data directory
data_head_dir = Path('/content/drive/MyDrive/552_project_data/data')

# Find all subframe directories
subdirs = [Path(subdir.stem) for subdir in data_head_dir.iterdir() if subdir.is_dir()]
src_image_ids = ['_'.join(a_path.name.split('_')[:3]) for a_path in subdirs]

# %%
# Load train/val/test subframe IDs
def load_text_ids(file_path):
    """Simple helper to load all lines from a text file"""
    with open(file_path, 'r') as f:
        lines = [line.strip() for line in f.readlines()]
    return lines

# Load the subframe names for the three data subsets
train_ids = load_text_ids('/content/drive/MyDrive/Colab Notebooks/train_source_images.txt')
validate_ids = load_text_ids('/content/drive/MyDrive/Colab Notebooks/val_source_images.txt')
test_ids = load_text_ids('/content/drive/MyDrive/Colab Notebooks/test_source_images.txt')

# Generate a list containing the dataset split for the matching subdirectory names
subdir_splits = []
for src_id in src_image_ids:
    if src_id in train_ids:
        subdir_splits.append('train')
    elif src_id in validate_ids:
        subdir_splits.append('validate')
    elif(src_id in test_ids):
        subdir_splits.append('test')
    else:
        logging.warning(f'{src_id}: Did not find designated split in train/validate/test list.')
        subdir_splits.append(None)

# %% [markdown]
# # Loading and pre processing the data
# ### Note that there are multiple ways to preprocess and load your data in order to train your model in tensorflow. We have provided one way to do it in the following cell. Feel free to use your own method and get better results.

# %%
import random
import tensorflow as tf
from PIL import Image

def load_and_preprocess(img_loc, label):

    def _inner_function(img_loc, label):

        # Convert tensor to native type
        img_loc_str = img_loc.numpy().decode('utf-8')
        label_str = label.numpy().decode('utf-8')

        img = Image.open(img_loc_str).convert('RGB')


        return img, 1 if label_str=='frost' else 0

    # Wrap the Python function
    X, y = tf.py_function(_inner_function, [img_loc, label], [tf.float32, tf.int64])

    return X, y


def load_subdir_data(dir_path, image_size, seed=None):

    """Helper to create a TF dataset from each image subdirectory"""

    # Grab only the classes that (1) we want to keep and (2) exist in this directory
    tile_dir = dir_path / Path('tiles')
    label_dir = dir_path /Path('labels')

    loc_list = []

    for folder in os.listdir(tile_dir):
        if os.path.isdir(os.path.join(tile_dir, folder)):
            for file in os.listdir(os.path.join(tile_dir, folder)):
                if file.endswith(".png"):
                    loc_list.append((os.path.join(os.path.join(tile_dir, folder), file), folder))

    return loc_list

# Loop over all subframes, loading each into a list
tf_data_train, tf_data_test, tf_data_val = [], [], []
tf_dataset_train, tf_dataset_test, tf_dataset_val = [], [], []

# Update the batch and buffer size as per your model requirements
buffer_size = 64
batch_size = 32

for subdir, split in zip(subdirs, subdir_splits):
    full_path = data_head_dir / subdir
    if split=='validate':
        tf_data_val.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))
    elif split=='train':
        tf_data_train.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))
    elif split=='test':
        tf_data_test.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))

random.shuffle(tf_data_train)
img_list, label_list = zip(*tf_data_train)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_train = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_train = tf_dataset_train.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_train = tf_dataset_train.shuffle(buffer_size=buffer_size).batch(batch_size)

random.shuffle(tf_data_val)
img_list, label_list = zip(*tf_data_val)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_val = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_val = tf_dataset_val.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=buffer_size).batch(batch_size)

random.shuffle(tf_data_test)
img_list, label_list = zip(*tf_data_test)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_test = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_test = tf_dataset_test.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_test = tf_dataset_test.shuffle(buffer_size=buffer_size).batch(batch_size)

# %%
print("\n\nTraining Set Length")
print(len(tf_dataset_train))
# Out:
# Training Set Length
# 442

# %%
print("\n\nTesting Set Length")
print(len(tf_dataset_test))
# Out:
# Testing Set Length
# 250

# %%
print("\n\nValidation Set Length")
print(len(tf_dataset_val))
# Out:
# Validation Set Length
# 247

# %% [markdown]
# ## Training CNN + MLP
# ###### i. To perform empirical regularization, crop, randomly zoom, rotate, flip, con- trast, and translate images in your training set for image augmentation. You can use various tools to do this, including OpenCV.

# %%
# !pip install --upgrade tensorflow-addons
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0.post1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow)
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.0.1
#     Uninstalling keras-3.0.1:
#       Successfully uninstalled keras-3.0.1
# Successfully installed keras-2.15.0

# %%
# https://github.com/zonna19/DSCI552-HWs/blob/main/Final%20Project/Hong_Seungil_Final_Project.ipynb
import tensorflow_addons as tfa

def augment(image, label):
    # Randomly change brightness
    image = tf.image.random_brightness(image, max_delta = 0.1)
    # Randomly change contrast
    image = tf.image.random_contrast(image, lower = 0.8, upper = 1.2)
    # Randomly rotate the image
    angle = tf.random.uniform([], minval = -math.pi/4, maxval = math.pi/4)  # Random angle in [-45, 45] degrees
    image = tfa.image.rotate(image, angle)

    # We do not need to flip images since those NASA generated images can be very rarely fliped.
    # Means assuming there are no artificial ones.
    # And Mars cannot be flimed with fliped images

    return image, label

# Apply the augment function to each element in the dataset
tf_dataset_train = tf_dataset_train.map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# c) ii) Train a three-layer CNN followed by a dense layer on the data. Choose the size of the kernels and depth of the layers and the number of neurons in the dense layer (MLP) on your own. Use ReLU’s in all of the layers. Use the softmax function, batch normalization3 and a dropout rate of 30%, L2 regularization, as well as ADAM optimizer. Use cross entropy loss. Train for at least 20 epochs and perform early stopping using the validation set. Keep the network parameters that have the lowest validation error. Plot the training and validation errors vs. epochs.

# %%
# Define the model
model = Sequential([
    # 1
    Conv2D(32, (3, 3), padding='same', input_shape=(299, 299, 3), kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    ReLU(),
    MaxPooling2D(pool_size=(2, 2)),

    # 2
    Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    ReLU(),
    MaxPooling2D(pool_size=(2, 2)),

    # 3
    Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    ReLU(),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(2, activation='softmax')  # for binary classification with softmax
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Early stopping and model checkpointing
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

history = model.fit(
    tf_dataset_train,
    epochs=20,
    validation_data=tf_dataset_val,
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-75a172207975> in <cell line: 8>()
#       6 model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)
#       7
# ----> 8 history = model.fit(
#       9     tf_dataset_train,
#      10     epochs=20,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1155, in train_step
#         return self.compute_metrics(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1249, in compute_metrics
#         self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 592, in update_state
#         self.build(y_pred, y_true)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 498, in build
#         self._metrics = tf.__internal__.nest.map_structure_up_to(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 646, in _get_metric_objects
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 646, in <listcomp>
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 667, in _get_metric_object
#         y_t_rank = len(y_t.shape.as_list())
#
#     ValueError: as_list() is not defined on an unknown TensorShape.

# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.3)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow)
#   Downloading tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 27.1 MB/s eta 0:00:00
# Collecting keras<2.16,>=2.15.0 (from tensorflow)
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.8 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Installing collected packages: tensorflow-estimator, keras, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
#     Uninstalling tensorflow-2.14.0:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed keras-2.15.0 tensorboard-2.15.1 tensorflow-2.15.0.post1 tensorflow-estimator-2.15.0
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting keras
#   Downloading keras-3.0.1-py3-none-any.whl (999 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 999.1/999.1 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.23.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.0)
# Collecting namex (from keras)
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Installing collected packages: namex, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.0.post1 requires keras<2.16,>=2.15.0, but you have keras 3.0.1 which is incompatible.
# Successfully installed keras-3.0.1 namex-0.0.7
